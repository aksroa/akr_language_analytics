# %% [markdown]
# __Comments:__

# %% [markdown]
# - It looks like the counting of unique words went wrong. Here all the count is from the same novel. Please, let me know if anyone know how to change this.
# - Also, I didnt know how to save the file with three columns.

# %%
import os

# %%
from pathlib import Path

# %%
data_path = os.path.join("..","data", "100_english_novels","corpus")

# %%
for filename in Path(data_path).glob("*.txt"):
    with open(filename, "r", encoding="utf-8") as file:
        lenght_text = file.read()
        split_text = lenght_text.split()
        print(f"{filename} is {len(split_text)} words.")
# Out:
# ../data/100_english_novels/corpus/Cbronte_Villette_1853.txt is 196557 words.
# ../data/100_english_novels/corpus/Forster_Angels_1905.txt is 50477 words.
# ../data/100_english_novels/corpus/Woolf_Lighthouse_1927.txt is 70185 words.
# ../data/100_english_novels/corpus/Meredith_Richmond_1871.txt is 214985 words.
# ../data/100_english_novels/corpus/Stevenson_Treasure_1883.txt is 68448 words.
# ../data/100_english_novels/corpus/Forster_Howards_1910.txt is 111057 words.
# ../data/100_english_novels/corpus/Wcollins_Basil_1852.txt is 118088 words.
# ../data/100_english_novels/corpus/Schreiner_Undine_1929.txt is 90672 words.
# ../data/100_english_novels/corpus/Galsworthy_Man_1906.txt is 110455 words.
# ../data/100_english_novels/corpus/Corelli_Innocent_1914.txt is 121950 words.
# ../data/100_english_novels/corpus/Kipling_Light_1891.txt is 72479 words.
# ../data/100_english_novels/corpus/Conrad_Nostromo_1904.txt is 172276 words.
# ...

# %%
import os

# %%
from pathlib import Path

# %%
data_path = os.path.join("..","data", "100_english_novels","corpus")

# %%
for filename in Path(data_path).glob("*.txt"):
    with open(filename, "r", encoding="utf-8") as file:
        lenght_text = file.read()
        split_text = lenght_text.split()
def freq(lenght_text):
    unique_list = lenght_text.split()
    unique_words = set(unique_list)
    for words in unique_words : 
            print(f"{filename} is {len(unique_words)} unique words.")

# %%
freq(lenght_text)
# Out:
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ../data/100_english_novels/corpus/Kipling_Captains_1896.txt is 11709 unique words.
# ...
